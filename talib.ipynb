# %%
import pandas as pd
import datetime

# %%
file2_name = "daily_trading_info_2019-2020.xlsx"
file2 = pd.read_excel(file2_name, sheet_name = None)
company_index = []
company_index = list(file2.keys())[:]

# %%
print(len(company_index))
# Out:
# 800

# %%
from talib import abstract

# %%
pd.read_excel(company_index[0]+".xlsx")
# Out:
#            date       open       high        low      close   volume
# 0    2014-01-02  21.309999  21.700001  21.230000  21.459999  5096443
# 1    2014-01-03  21.400000  21.450001  20.370001  20.790001  9945683
# 2    2014-01-06  20.680000  20.680000  20.219999  20.240000  5171376
# 3    2014-01-07  20.100000  20.250000  19.860001  20.000000  5364241
# 4    2014-01-08  20.000000  20.389999  20.000000  20.230000  5186841
# ...         ...        ...        ...        ...        ...      ...
# 1517 2020-03-25  24.600000  24.850000  24.500000  24.799999  7072723
# 1518 2020-03-26  24.620001  25.290001  24.580000  25.129999  8346083
# 1519 2020-03-27  25.320000  25.799999  25.150000  25.180000  8794212
# 1520 2020-03-30  25.150000  25.570000  24.950001  25.450001  8179292
# 1521 2020-03-31  25.500000  25.540001  25.150000  25.350000  5331630
#
# [1522 rows x 6 columns]

# %%
df = pd.read_excel(company_index[0]+".xlsx")

# %%
inputs = {
    'open': df["open"],
    'high': df["high"],
    'low':  df["low"],
    'close': df["close"],
    'volume': df["volume"]
}
# uses close prices (default)
out1 = abstract.ADX(inputs, timeperiod = 14)
out2 = abstract.RSI(inputs, timeperiod=14)
out3 = abstract.MACD(inputs)[0]

# %%
pd.DataFrame(out1, columns=["ADX"]).head(100)
# Out:
#           ADX
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 95  30.454856
# 96  28.862426
# 97  26.953289
# 98  25.777284
# 99  24.582969
#
# [100 rows x 1 columns]

# %%
pd.DataFrame(out2, columns=["RSI"]).tail(10)
# Out:
#             RSI
# 1512  28.583022
# 1513  25.030064
# 1514  29.187648
# 1515  26.876271
# 1516  30.341627
# 1517  37.345845
# 1518  41.862185
# 1519  42.538062
# 1520  46.176777
# 1521  45.039201

# %%
pd.DataFrame(out3, columns=["MACD"]).tail(10)
# Out:
#           MACD
# 1512 -0.623331
# 1513 -0.707910
# 1514 -0.746165
# 1515 -0.796351
# 1516 -0.809844
# 1517 -0.774491
# 1518 -0.711642
# 1519 -0.650302
# 1520 -0.573295
# 1521 -0.514406

# %%
out1
# Out:
# array([        nan,         nan,         nan, ..., 25.63233839,
#        24.38117217, 23.21937497])

# %%
pd.concat([df, pd.DataFrame(out1, columns=["ADX"])\
          , pd.DataFrame(out2, columns=["RSI"]), pd.DataFrame(out3, columns=["MACD"])], axis=1).head(30)
# Out:
#          date       open       high        low      close    volume  \
# 0  2014-01-02  21.309999  21.700001  21.230000  21.459999   5096443
# 1  2014-01-03  21.400000  21.450001  20.370001  20.790001   9945683
# 2  2014-01-06  20.680000  20.680000  20.219999  20.240000   5171376
# 3  2014-01-07  20.100000  20.250000  19.860001  20.000000   5364241
# 4  2014-01-08  20.000000  20.389999  20.000000  20.230000   5186841
# 5  2014-01-09  20.200001  20.290001  19.969999  20.020000   3824827
# 6  2014-01-10  19.900000  20.010000  18.959999  19.240000   9143400
# 7  2014-01-13  19.299999  19.299999  19.010000  19.219999   4283805
# 8  2014-01-14  19.219999  19.559999  19.120001  19.490000   3426150
# 9  2014-01-15  19.490000  20.000000  19.490000  19.830000   4878185
# 10 2014-01-16  19.840000  20.100000  19.760000  19.910000   2931624
# 11 2014-01-17  20.010000  20.010000  19.600000  19.730000   2813683
# 12 2014-01-20  19.600000  19.709999  19.250000  19.430000   4621019
# 13 2014-01-21  19.490000  20.070000  19.430000  19.980000   2911691
# 14 2014-01-22  19.980000  20.110001  19.750000  20.100000   4602530
# 15 2014-01-23  20.100000  20.150000  19.879999  19.920000   3955330
# 16 2014-01-24  19.950001  20.070000  19.410000  19.540001   8548517
# 17 2014-01-27  19.469999  19.469999  19.030001  19.070000   7097953
# 18 2014-01-28  19.059999  19.450001  19.030001  19.129999   5427807
# 19 2014-01-29  19.180000  19.270000  18.879999  18.980000   6456224
# 20 2014-01-30  19.000000  19.040001  18.379999  18.580000   6490546
# 21 2014-02-07  18.549999  18.980000  18.520000  18.700001   8121576
# 22 2014-02-10  18.770000  19.280001  18.730000  19.100000  12382450
# 23 2014-02-11  19.170000  20.150000  19.100000  19.889999  17814676
# 24 2014-02-12  19.920000  20.030001  19.680000  19.910000   6691717
# 25 2014-02-13  19.889999  19.889999  19.500000  19.610001   6408027
# 26 2014-02-14  19.540001  19.820000  19.540001  19.690001   5257374
# 27 2014-02-17  19.820000  19.889999  19.580000  19.719999   6782577
# 28 2014-02-18  19.730000  19.730000  19.180000  19.240000  12105300
# 29 2014-02-19  19.230000  19.290001  18.969999  19.129999  10187290
#
#           ADX        RSI  MACD
# 0         NaN        NaN   NaN
# 1         NaN        NaN   NaN
# 2         NaN        NaN   NaN
# 3         NaN        NaN   NaN
# 4         NaN        NaN   NaN
# 5         NaN        NaN   NaN
# 6         NaN        NaN   NaN
# 7         NaN        NaN   NaN
# 8         NaN        NaN   NaN
# 9         NaN        NaN   NaN
# 10        NaN        NaN   NaN
# 11        NaN        NaN   NaN
# 12        NaN        NaN   NaN
# 13        NaN        NaN   NaN
# 14        NaN  35.022037   NaN
# 15        NaN  33.587918   NaN
# 16        NaN  30.727285   NaN
# 17        NaN  27.596624   NaN
# 18        NaN  28.596769   NaN
# 19        NaN  27.571377   NaN
# 20        NaN  24.997308   NaN
# 21        NaN  27.193358   NaN
# 22        NaN  34.117924   NaN
# 23        NaN  45.202816   NaN
# 24        NaN  45.453042   NaN
# 25        NaN  42.330604   NaN
# 26        NaN  43.446300   NaN
# 27  36.026157  43.884710   NaN
# 28  35.280580  38.713377   NaN
# 29  34.907883  37.619322   NaN

# %%
for w in range(0, len(company_index)):
    df = pd.read_excel(company_index[w]+".xlsx")
    inputs = {
    'open': df["open"],
    'high': df["high"],
    'low':  df["low"],
    'close': df["close"],
    'volume': df["volume"]
    }
    # uses close prices (default)
    out1 = abstract.SMA(inputs, timeperiod=5)
    out2 = abstract.SMA(inputs, timeperiod=10)
    out3 = abstract.SMA(inputs, timeperiod=15)
    a =  pd.DataFrame(out1, columns=["ADX"])
    b = pd.DataFrame(out2, columns=["RSI"])
    c = pd.DataFrame(out3, columns=["MACD"])
    pd.concat([df,a , b, c], axis=1).to_excel(company_index[w]+".xlsx", \
                                              sheet_name = company_index[w], index=False)
    if(w%100==0):
        print(w)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700

# %%
train_set = pd.read_excel("strategy_results_train.xlsx")

# %%
import copy

# %%
dataset = copy.deepcopy(train_set)

# %%
temp = []
for i in range(0, dataset.shape[0]):
# for i in range(0, 10):
    if(i%1000==0):
        print(i, datetime.datetime.now())
    trade_company = dataset.iloc[i][0].split("_")[0]
    trade_date    = dataset.iloc[i][0].split("_")[1]
    df = pd.read_excel(trade_company+".xlsx")
    trade_date_datetime = datetime.date(int(trade_date[:4]), int(trade_date[4:]), 1) - datetime.timedelta(days=1)
    lower_index = 0
    for index in range(0, df.shape[0]):
        if(df["date"].iloc[index]< trade_date_datetime):
            lower_index = index
        else:
            break
#     print(list(df.iloc[lower_index, :]))
    temp.append(list(df.iloc[lower_index, :]))
# Out:
# 0 2020-06-22 18:11:30.387002
# 1000 2020-06-22 18:15:08.976019
# 2000 2020-06-22 18:19:17.215028
# 3000 2020-06-22 18:22:48.247678
# 4000 2020-06-22 18:26:08.309185
# 5000 2020-06-22 18:29:21.076253
# 6000 2020-06-22 18:32:49.746300
# 7000 2020-06-22 18:36:23.069387
# 8000 2020-06-22 18:39:44.070411
# 9000 2020-06-22 18:43:03.342736
# 10000 2020-06-22 18:46:12.795624
# 11000 2020-06-22 18:49:36.879915
# 12000 2020-06-22 18:53:02.934003
# 13000 2020-06-22 18:56:29.202825
# 14000 2020-06-22 18:59:55.293147
# 15000 2020-06-22 19:03:20.977924
# 16000 2020-06-22 19:06:41.704957
# 17000 2020-06-22 19:10:07.895835
# 18000 2020-06-22 19:13:18.278182
# 19000 2020-06-22 19:18:28.452841
# 20000 2020-06-22 19:22:08.150922
# 21000 2020-06-22 19:25:27.200486
# 22000 2020-06-22 19:28:54.831722
# 23000 2020-06-22 19:32:33.922760
# 24000 2020-06-22 19:36:16.749584
# 25000 2020-06-22 19:39:33.992539
# 26000 2020-06-22 19:42:56.252560
# 27000 2020-06-22 19:46:03.023352
# 28000 2020-06-22 19:49:32.722256
# 29000 2020-06-22 19:52:48.337512
# 30000 2020-06-22 19:56:13.123612
# 31000 2020-06-22 19:59:19.154893

# %%
temp[1]
# Out:
# [Timestamp('2015-01-30 00:00:00'),
#  22.98999977111816,
#  23.19000053405762,
#  22.51000022888184,
#  22.57999992370605,
#  7880595,
#  23.32000007629394,
#  23.38600006103515,
#  23.59000002543132]

# %%
pd.DataFrame(temp).to_excel("train_output.xlsx", index=False)

# %%
testset = pd.read_excel("sampleSubmission.xlsx")

# %%
testset.head()
# Out:
#                    id  label
# 0  SHSE.600085_201901      0
# 1  SHSE.600085_201902      0
# 2  SHSE.600085_201903      0
# 3  SHSE.600085_201904      0
# 4  SHSE.600085_201905      0

# %%
temp = []
for i in range(0, testset.shape[0]):
# for i in range(0, 10):
    if(i%1000==0):
        print(i, datetime.datetime.now())
    trade_company = testset.iloc[i][0].split("_")[0]
    trade_date    = testset.iloc[i][0].split("_")[1]
    df = pd.read_excel(trade_company+".xlsx")
    trade_date_datetime = datetime.date(int(trade_date[:4]), int(trade_date[4:]), 1) - datetime.timedelta(days=1)
    lower_index = 0
    for index in range(0, df.shape[0]):
        if(df["date"].iloc[index]< trade_date_datetime):
            lower_index = index
        else:
            break
#     print(list(df.iloc[lower_index, :]))
    if(lower_index==0):
        temp.append(dash = ["-","","","","","","","",""])
    else:
        temp.append(list(df.iloc[lower_index, :]))
# Out:
# 0 2020-06-22 20:08:23.262450
# 1000 2020-06-22 20:12:14.696306
# 2000 2020-06-22 20:15:47.776284
# 3000 2020-06-22 20:19:17.199166
# 4000 2020-06-22 20:22:29.567251
# 5000 2020-06-22 20:26:24.123776
# 6000 2020-06-22 20:30:13.702494
# 7000 2020-06-22 20:33:37.129802
# 8000 2020-06-22 20:36:59.054104
# 9000 2020-06-22 20:40:15.283625
# 10000 2020-06-22 20:43:35.915480
# 11000 2020-06-22 20:46:30.918854

# %%
pd.DataFrame(temp).to_excel("test_output.xlsx", index=False)

# %%
temp[0]
# Out:
# [Timestamp('2018-12-28 00:00:00'),
#  27.18000030517578,
#  27.57999992370605,
#  26.98999977111816,
#  27.5,
#  3575585,
#  27.25800018310547,
#  27.57299995422363,
#  28.19799995422363]

# %%
dash = ["-","","","","","","","",""]
